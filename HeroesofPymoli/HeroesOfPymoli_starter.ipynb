# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load
purchases = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(purchases)
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
#the total number of players
total_players = len(purchase_data['SN'].value_counts())

#create a data frame with total players named player count
player_count = pd.DataFrame({"Total Players":[total_players]})
player_count
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#* Number of Unique Items
Items = len(purchase_data['Item ID'].value_counts())
Items

#* Average Purchase Price
avg_price=purchase_data["Price"].mean()
avg_price

#* Total Number of Purchases
numpur=len(purchase_data["Item Name"])
numpur

#* Total Revenue
total_rev= purchase_data["Price"].sum()
total_rev


#print summation data frame
purch_analysis=pd.DataFrame({"Unique Items":[Items],
                             "Average Purchase Price":[avg_price],
                             "Total Number of Purchases":[numpur],
                             "Total Revenue":[total_rev]})
purch_analysis=purch_analysis.round(2)
purch_analysis
# Out:
#    Unique Items  Average Purchase Price  Total Number of Purchases  \
# 0           179                    3.05                        780
#
#    Total Revenue
# 0        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#percentage and count of Male Players
#percentage and count of Female Players
#percentage and count of other/non-disclosed players
gender_stats.df = purchase_data.groupby(["Gender"])
Players=gender_stats.df["SN"].count()

#percentage calculation
player_per=(Players/total_players)*100

#create summation dataframe
gender_summ= pd.DataFrame({"Number of Players": Players,
                                    "Percentage":player_per})
gender_summ= gender_summ.round(2)
gender_summ
# Out:
#                        Number of Players  Percentage
# Gender
# Female                               113       19.62
# Male                                 652      113.19
# Other / Non-Disclosed                 15        2.60

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#purchase count analyasis
#create dataframe with desired columns
Purch_analysis_gender=purchase_data[["SN", "Gender", "Item ID", "Price"]]

#seperate created dataframe by gender as the index
grouped_Pur_data.df= Purch_analysis_gender.groupby(['Gender'])

#calculations 
Purchase_count_gender= grouped_Pur_data.df['Item ID'].count()
Avg_Pur_Price = grouped_Pur_data.df['Price'].mean()
Total_Pur=grouped_Pur_data.df['Price'].sum()
Avg_Pur_Person= (Total_Pur/Purchase_count_gender)

#creation of summation dataframe 
purchase_summ=pd.DataFrame({"Purchase Count":Purchase_count_gender,
                            "Average Purchase Price":Avg_Pur_Price,
                            "Total Purchase Value":Total_Pur,
                            "Avg Total Purchase Per Person":Avg_Pur_Person})
purchase_summ=purchase_summ.round(2)
purchase_summ
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                    3.20
# Male                              652                    3.02
# Other / Non-Disclosed              15                    3.35
#
#                        Total Purchase Value  Avg Total Purchase Per Person
# Gender
# Female                               361.94                           3.20
# Male                                1967.64                           3.02
# Other / Non-Disclosed                 50.19                           3.35

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
#Age Demographics 
Age_demo= purchase_data["Age"]

#create bins to hold the data
bins = [0,10,15,20,25,30,35,40,100]

#create the names for the bins
age_cat=['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']



Age_demo["Age Category"] = pd.cut(Age_demo, bins, labels=age_cat, include_lowest=True)
Age_demo

Age_totals=Age_demo["Age Category"].value_counts()
Age_perc=((Age_totals/total_players)*100)

Summ_Age_demo=pd.DataFrame({"Age Group Total":Age_totals, "Age Group Percentage":Age_perc})
Summ_Age_demo=Summ_Age_demo.round(2)
Summ_Age_demo
# Out:
# <ipython-input-154-f5f9ef2ba6a4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Age_demo["Age Category"] = pd.cut(Age_demo, bins, labels=age_cat, include_lowest=True)
#        Age Group Total  Age Group Percentage
# 20-24              325                 56.42
# 15-19              200                 34.72
# 25-29               77                 13.37
# 10-14               54                  9.38
# 30-34               52                  9.03
# 35-39               33                  5.73
# <10                 32                  5.56
# 40+                  7                  1.22

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#create the dataframe pulling desired series from original data
Purch_byAge=purchase_data[["SN", "Age", "Item ID", "Price"]] 

#bin the ages of the dataframe
#create bins to hold the data
bins = [0,10,15,20,25,30,35,40,100]

#create the names for the bins
age_cat=['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']

Purch_byAge["Age Category"] = pd.cut(Purch_byAge["Age"], bins, labels=age_cat, include_lowest=True)

#calculations 
Purchase_count_Age=Purch_byAge['Item ID'].count()
Avg_Pur_Price_Age = Purch_byAge['Price'].mean()
Total_Pur_Age=Purch_byAge['Price'].sum()
Avg_Pur_Person_Age= (Total_Pur_Age/Purchase_count_Age)


#creation of summation dataframe 
Purch_Age_summ=pd.DataFrame({"Purchase Count":Purchase_count_Age,
                            "Average Purchase Price":Avg_Pur_Price_Age,
                            "Total Purchase Value":Total_Pur_Age,
                            "Avg Total Purchase Per Person":Avg_Pur_Person_Age})
Purch_Age_summ=Purch_Age_summ.round(2)
Purch_Age_summ
# Out:
# <ipython-input-159-f84a00b10e27>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Purch_byAge["Age Category"] = pd.cut(Purch_byAge["Age"], bins, labels=age_cat, include_lowest=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-f84a00b10e27> in <module>
#      19
#      20 #creation of summation dataframe
# ---> 21 Purch_Age_summ=pd.DataFrame({"Purchase Count":Purchase_count_Age,
#      22                             "Average Purchase Price":Avg_Pur_Price_Age,
#      23                             "Total Purchase Value":Total_Pur_Age,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     389
#     390         if not indexes and not raw_lengths:
# --> 391             raise ValueError("If using all scalar values, you must pass an index")
#     392
#     393         if have_series:
#
# ValueError: If using all scalar values, you must pass an index

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 145     Fiery Glass Crusader                                      9
# 132     Persuasion                                                9
# 108     Extraction, Quickblade Of Trembling Hands                 9
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 145     Fiery Glass Crusader                              $4.58
# 132     Persuasion                                        $3.22
# 108     Extraction, Quickblade Of Trembling Hands         $3.53
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 145     Fiery Glass Crusader                                       $41.22
# 132     Persuasion                                                 $28.99
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Out:
#                                                      Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                             13
# 178     Oathbreaker, Last Hope of the Breaking Storm             12
# 82      Nirvana                                                   9
# 145     Fiery Glass Crusader                                      9
# 103     Singed Scalpel                                            8
#
#                                                      Item Price  \
# Item ID Item Name
# 92      Final Critic                                      $4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm      $4.23
# 82      Nirvana                                           $4.90
# 145     Fiery Glass Crusader                              $4.58
# 103     Singed Scalpel                                    $4.35
#
#                                                      Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                               $59.99
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 82      Nirvana                                                    $44.10
# 145     Fiery Glass Crusader                                       $41.22
# 103     Singed Scalpel                                             $34.80
